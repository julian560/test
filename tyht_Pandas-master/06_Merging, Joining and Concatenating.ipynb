# %%
import pandas as pd

# %%
ubike_date = pd.read_csv("ubike-utf8.csv", usecols=['日期','場站區域'], nrows=100)
ubike_areas = pd.read_csv("ubike-utf8.csv", usecols=['日期','場站區域'],nrows=100)

# %%
ubike_date.head()
ubike_areas.head()
# Out:
#            日期 場站區域
# 0  2014-12-08  大安區
# 1  2014-12-08  信義區
# 2  2014-12-08  信義區
# 3  2014-12-08  信義區
# 4  2014-12-08  信義區

# %% [markdown]
# ## The `pd.concat()` Method, Part 1

# %%
len(ubike_date)
# Out:
# 100

# %%
len(ubike_areas)
# Out:
# 100

# %%
len(pd.concat([ubike_date, ubike_areas],axis=1))
# Out:
# 100

# %%
pd.concat([ubike_date, ubike_areas], keys=['ubike_date','ubike_areas'])
# Out:
#                         日期 場站區域
# ubike_date  0   2014-12-08  大安區
#             1   2014-12-08  信義區
#             2   2014-12-08  信義區
#             3   2014-12-08  信義區
#             4   2014-12-08  信義區
#             5   2014-12-08  信義區
#             6   2014-12-08  信義區
#             7   2014-12-08  信義區
#             8   2014-12-08  信義區
#             9   2014-12-08  信義區
#             10  2014-12-08  信義區
#             11  2014-12-08  信義區
#             12  2014-12-08  中山區
#             13  2014-12-08  松山區
#             14  2014-12-08  信義區
#             15  2014-12-08  松山區
#             16  2014-12-08  松山區
#             17  2014-12-08  信義區
#             18  2014-12-08  大安區
#             19  2014-12-08  松山區
#             20  2014-12-08  松山區
#             21  2014-12-08  南港區
#             22  2014-12-08  大安區
#             23  2014-12-08  信義區
#             24  2014-12-08  南港區
#             25  2014-12-08  南港區
#             26  2014-12-08  信義區
#             27  2014-12-08  大安區
#             28  2014-12-08  大安區
#             29  2014-12-08  大安區
# ...                    ...  ...
# ubike_areas 70  2014-12-08  中山區
#             71  2014-12-08  大同區
#             72  2014-12-08  中正區
#             73  2014-12-08  信義區
#             74  2014-12-08  中山區
#             75  2014-12-08  松山區
#             76  2014-12-08  大同區
#             77  2014-12-08  大同區
#             78  2014-12-08  萬華區
#             79  2014-12-08  大安區
#             80  2014-12-08  中正區
#             81  2014-12-08  大安區
#             82  2014-12-08  萬華區
#             83  2014-12-08  大安區
#             84  2014-12-08  松山區
#             85  2014-12-08  大安區
#             86  2014-12-08  信義區
#             87  2014-12-08  中正區
#             88  2014-12-08  萬華區
#             89  2014-12-08  中山區
#             90  2014-12-08  萬華區
#             91  2014-12-08  信義區
#             92  2014-12-08  文山區
#             93  2014-12-08  萬華區
#             94  2014-12-08  松山區
#             95  2014-12-08  士林區
#             96  2014-12-08  文山區
#             97  2014-12-08  大同區
#             98  2014-12-08  中正區
#             99  2014-12-08  中正區
#
# [200 rows x 2 columns]

# %% [markdown]
# ## The `.append()` Method

# %%
sales = ubike_areas.append(ubike_date, ignore_index = True)

# %%
sales
# Out:
#     場站區域          日期
# 0    大安區         NaN
# 1    信義區         NaN
# 2    信義區         NaN
# 3    信義區         NaN
# 4    信義區         NaN
# 5    信義區         NaN
# 6    信義區         NaN
# 7    信義區         NaN
# 8    信義區         NaN
# 9    信義區         NaN
# 10   信義區         NaN
# 11   信義區         NaN
# 12   中山區         NaN
# 13   松山區         NaN
# 14   信義區         NaN
# 15   松山區         NaN
# 16   松山區         NaN
# 17   信義區         NaN
# 18   大安區         NaN
# 19   松山區         NaN
# 20   松山區         NaN
# 21   南港區         NaN
# 22   大安區         NaN
# 23   信義區         NaN
# 24   南港區         NaN
# 25   南港區         NaN
# 26   信義區         NaN
# 27   大安區         NaN
# 28   大安區         NaN
# 29   大安區         NaN
# ..   ...         ...
# 170  NaN  2014-12-08
# 171  NaN  2014-12-08
# 172  NaN  2014-12-08
# 173  NaN  2014-12-08
# 174  NaN  2014-12-08
# 175  NaN  2014-12-08
# 176  NaN  2014-12-08
# 177  NaN  2014-12-08
# 178  NaN  2014-12-08
# 179  NaN  2014-12-08
# 180  NaN  2014-12-08
# 181  NaN  2014-12-08
# 182  NaN  2014-12-08
# 183  NaN  2014-12-08
# 184  NaN  2014-12-08
# 185  NaN  2014-12-08
# 186  NaN  2014-12-08
# 187  NaN  2014-12-08
# 188  NaN  2014-12-08
# 189  NaN  2014-12-08
# 190  NaN  2014-12-08
# 191  NaN  2014-12-08
# 192  NaN  2014-12-08
# 193  NaN  2014-12-08
# 194  NaN  2014-12-08
# 195  NaN  2014-12-08
# 196  NaN  2014-12-08
# 197  NaN  2014-12-08
# 198  NaN  2014-12-08
# 199  NaN  2014-12-08
#
# [200 rows x 2 columns]

# %% [markdown]
# ## Inner Joins, Part 1

# %%
ubike_data = pd.read_csv("ubike-utf8.csv", usecols=['日期','場站區域','平均車輛數'])

# %%
x1 = ubike_data[1:100]

# %%
x2 = ubike_data[101:200]

# %%
x1.head(2)
# Out:
#            日期 場站區域   平均車輛數
# 1  2014-12-08  信義區  10.333
# 2  2014-12-08  信義區  39.333

# %%
x2.head(2)
# Out:
#              日期 場站區域  平均車輛數
# 101  2014-12-08  萬華區  8.833
# 102  2014-12-08  文山區  8.667

# %%
x1.merge(x2, how = "inner", on = "日期", suffixes=[' - A', '- B'])
# Out:
#               日期 場站區域 - A  平均車輛數 - A 場站區域- B  平均車輛數- B
# 0     2014-12-08      信義區     10.333     萬華區     8.833
# 1     2014-12-08      信義區     10.333     文山區     8.667
# 2     2014-12-08      信義區     10.333     萬華區    14.833
# 3     2014-12-08      信義區     10.333     萬華區    14.000
# 4     2014-12-08      信義區     10.333     中正區    10.167
# 5     2014-12-08      信義區     10.333     大同區     3.000
# 6     2014-12-08      信義區     10.333     中山區     8.000
# 7     2014-12-08      信義區     10.333     內湖區    26.429
# 8     2014-12-08      信義區     10.333     大安區    35.833
# 9     2014-12-08      信義區     10.333     北投區    20.286
# 10    2014-12-08      信義區     10.333     信義區    11.000
# 11    2014-12-08      信義區     10.333     士林區    16.167
# 12    2014-12-08      信義區     10.333     中正區    15.500
# 13    2014-12-08      信義區     10.333     士林區    12.500
# 14    2014-12-08      信義區     10.333     北投區    19.500
# 15    2014-12-08      信義區     10.333     北投區     2.667
# 16    2014-12-08      信義區     10.333     中山區    18.167
# 17    2014-12-08      信義區     10.333     萬華區    28.000
# 18    2014-12-08      信義區     10.333     中山區    39.000
# 19    2014-12-08      信義區     10.333     內湖區     7.167
# 20    2014-12-08      信義區     10.333     士林區    31.000
# 21    2014-12-08      信義區     10.333     北投區    19.667
# 22    2014-12-08      信義區     10.333     萬華區     5.667
# 23    2014-12-08      信義區     10.333     大安區    19.667
# 24    2014-12-08      信義區     10.333     內湖區    27.667
# 25    2014-12-08      信義區     10.333     大安區    20.429
# 26    2014-12-08      信義區     10.333     內湖區    30.000
# 27    2014-12-08      信義區     10.333     中正區     3.143
# 28    2014-12-08      信義區     10.333     內湖區    17.833
# 29    2014-12-08      信義區     10.333     大安區    13.833
# ...          ...      ...        ...     ...       ...
# 9771  2014-12-08      中正區     21.833     中山區    15.333
# 9772  2014-12-08      中正區     21.833     松山區    42.500
# 9773  2014-12-08      中正區     21.833     松山區    29.167
# 9774  2014-12-08      中正區     21.833     中山區    50.571
# 9775  2014-12-08      中正區     21.833     士林區    23.000
# 9776  2014-12-08      中正區     21.833     內湖區    18.000
# 9777  2014-12-08      中正區     21.833     中正區    26.333
# 9778  2014-12-08      中正區     21.833     中山區    19.333
# 9779  2014-12-08      中正區     21.833     中山區    37.500
# 9780  2014-12-08      中正區     21.833     新店區    18.000
# 9781  2014-12-08      中正區     21.833     汐止區    13.000
# 9782  2014-12-08      中正區     21.833     汐止區    23.500
# 9783  2014-12-08      中正區     21.833     汐止區    27.000
# 9784  2014-12-08      中正區     21.833     新店區    26.667
# 9785  2014-12-08      中正區     21.833     新店區    11.000
# 9786  2014-12-08      中正區     21.833     汐止區     8.000
# 9787  2014-12-08      中正區     21.833     三重區    19.167
# 9788  2014-12-08      中正區     21.833     三重區    18.833
# 9789  2014-12-08      中正區     21.833     三重區     9.000
# 9790  2014-12-08      中正區     21.833     汐止區    33.000
# 9791  2014-12-08      中正區     21.833     汐止區    28.000
# 9792  2014-12-08      中正區     21.833     汐止區    15.000
# 9793  2014-12-08      中正區     21.833     新莊區    19.167
# 9794  2014-12-08      中正區     21.833     新莊區    17.833
# 9795  2014-12-08      中正區     21.833     新莊區    19.000
# 9796  2014-12-08      中正區     21.833     新店區    23.000
# 9797  2014-12-08      中正區     21.833     蘆洲區     4.000
# 9798  2014-12-08      中正區     21.833     三重區    16.833
# 9799  2014-12-08      中正區     21.833     三重區    30.667
# 9800  2014-12-08      中正區     21.833     新莊區    23.333
#
# [9801 rows x 5 columns]

# %% [markdown]
# ## Inner Joins, Part 2

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
week1.merge(week2, how = "inner", on = ["Customer ID", "Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1[week1["Customer ID"] == 578]
# Out:
#      Customer ID  Food ID
# 224          578        5

# %%
week2[week2["Customer ID"] == 578]
# Out:
#      Customer ID  Food ID
# 29           578        5
# 189          578        5

# %% [markdown]
# ## Outer Joins

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
merged = week1.merge(week2, how = "outer", on = "Customer ID", suffixes = [" - Week 1", " - Week 2"],
            indicator = True)

# %%
merged["_merge"].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
mask = merged["_merge"].isin(["left_only", "right_only"])
merged[mask]
# Out:
#      Customer ID  Food ID - Week 1  Food ID - Week 2      _merge
# 1           97.0               4.0               NaN   left_only
# 2          658.0               1.0               NaN   left_only
# 3          202.0               2.0               NaN   left_only
# 6          213.0               8.0               NaN   left_only
# 7          600.0               1.0               NaN   left_only
# 10          71.0               3.0               NaN   left_only
# 11          71.0               8.0               NaN   left_only
# 12         174.0               3.0               NaN   left_only
# 13         961.0               9.0               NaN   left_only
# 14         966.0               5.0               NaN   left_only
# 15         641.0               4.0               NaN   left_only
# 16         288.0               2.0               NaN   left_only
# 17         149.0               4.0               NaN   left_only
# 18         954.0               2.0               NaN   left_only
# 19         147.0               9.0               NaN   left_only
# 20         147.0               8.0               NaN   left_only
# 23         549.0               6.0               NaN   left_only
# 25          78.0               7.0               NaN   left_only
# 26         514.0               5.0               NaN   left_only
# 27         833.0               7.0               NaN   left_only
# 28         833.0               3.0               NaN   left_only
# 29         329.0               8.0               NaN   left_only
# 30         586.0              10.0               NaN   left_only
# 31         341.0               1.0               NaN   left_only
# 32         519.0              10.0               NaN   left_only
# 33         680.0               9.0               NaN   left_only
# 34         419.0               7.0               NaN   left_only
# 35          20.0               1.0               NaN   left_only
# 36         822.0               6.0               NaN   left_only
# 37         226.0              10.0               NaN   left_only
# ..           ...               ...               ...         ...
# 424        622.0               NaN               9.0  right_only
# 425        959.0               NaN               4.0  right_only
# 426        959.0               NaN               2.0  right_only
# 427        810.0               NaN               2.0  right_only
# 428        488.0               NaN               2.0  right_only
# 429        188.0               NaN               8.0  right_only
# 430        305.0               NaN               2.0  right_only
# 431        869.0               NaN               7.0  right_only
# 432        131.0               NaN               1.0  right_only
# 433        208.0               NaN               4.0  right_only
# 434        145.0               NaN               5.0  right_only
# 435        794.0               NaN               6.0  right_only
# 436        734.0               NaN              10.0  right_only
# 437        734.0               NaN               1.0  right_only
# 438        735.0               NaN               2.0  right_only
# 439        940.0               NaN               8.0  right_only
# 440        571.0               NaN               7.0  right_only
# 441        888.0               NaN               2.0  right_only
# 442        664.0               NaN               6.0  right_only
# 443        143.0               NaN               4.0  right_only
# 444        505.0               NaN               3.0  right_only
# 445         54.0               NaN               8.0  right_only
# 446        367.0               NaN               8.0  right_only
# 447        883.0               NaN               8.0  right_only
# 448        251.0               NaN               9.0  right_only
# 449        855.0               NaN               4.0  right_only
# 450        559.0               NaN              10.0  right_only
# 451        276.0               NaN               4.0  right_only
# 452        556.0               NaN              10.0  right_only
# 453        252.0               NaN               9.0  right_only
#
# [392 rows x 4 columns]

# %% [markdown]
# ## Left Joins

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
foods.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %%
week1 = week1.merge(foods, how = "left", on = "Food ID", sort = True)

# %%
week1.head()
# Out:
#    Customer ID  Food ID Food Item  Price
# 0          658        1     Sushi   3.99
# 1          600        1     Sushi   3.99
# 2          155        1     Sushi   3.99
# 3          341        1     Sushi   3.99
# 4           20        1     Sushi   3.99

# %% [markdown]
# ## The `left_on` and `right_on` Parameters

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
week2 = week2.merge(customers, how = "left", left_on = "Customer ID", right_on = "ID", sort = True).drop("ID", axis = "columns")

# %%
week2.head()
# Out:
#    Customer ID  Food ID First Name Last Name  Gender        Company  \
# 0            8        6    Frances     Adams  Female       Dabshots
# 1           13        2       Ruth   Alvarez  Female    Twitterlist
# 2           21        4     Albert     Burns    Male      Rhynoodle
# 3           24        8      Donna    Thomas  Female        Jaxbean
# 4           27        4    Jessica   Bennett  Female  Twitternation
#
#                     Occupation
# 0                Developer III
# 1  Mechanical Systems Engineer
# 2             Junior Executive
# 3        Chief Design Engineer
# 4            Account Executive

# %% [markdown]
# ## Merging by Indexes with the `left_index` and `right_index` Parameters

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv", index_col = "ID")
foods = pd.read_csv("Restaurant - Foods.csv", index_col = "Food ID")

# %%
foods.head(3)
# Out:
#         Food Item  Price
# Food ID
# 1           Sushi   3.99
# 2         Burrito   9.99
# 3            Taco   2.99

# %%
sales = week1.merge(customers, how = "left", left_on = "Customer ID", right_index = True)
sales = sales.merge(foods, how = "left", left_on = "Food ID", right_index = True)
sales.head(3)
# Out:
#    Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0          537        9     Cheryl   Carroll  Female   Zoombeat
# 1           97        4     Amanda   Watkins  Female        Ozu
# 2          658        1    Patrick      Webb    Male  Browsebug
#
#                       Occupation   Food Item  Price
# 0               Registered Nurse       Donut   0.99
# 1            Account Coordinator  Quesadilla   4.25
# 2  Community Outreach Specialist       Sushi   3.99

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
week1.merge(week2, how = "left", left_index = True, right_index = True, suffixes = [" - Week 1", " - Week 2"])
# Out:
#      Customer ID - Week 1  Food ID - Week 1  Customer ID - Week 2  \
# 0                     537                 9                   688
# 1                      97                 4                   813
# 2                     658                 1                   495
# 3                     202                 2                   189
# 4                     155                 9                   267
# 5                     213                 8                   310
# 6                     600                 1                   761
# 7                     503                 5                   443
# 8                      71                 3                   729
# 9                     174                 3                   741
# 10                    961                 9                   847
# 11                    966                 5                   156
# 12                    641                 4                   550
# 13                    288                 2                   620
# 14                    149                 4                   272
# 15                    954                 2                   511
# 16                    147                 9                     8
# 17                    155                 1                   534
# 18                    550                 6                   909
# 19                    101                 7                   732
# 20                    549                 6                   372
# 21                     75                 6                   713
# 22                     78                 7                   496
# 23                    514                 5                   381
# 24                    833                 7                    13
# 25                    329                 8                   101
# 26                    586                10                   325
# 27                    341                 1                   674
# 28                    519                10                   564
# 29                    680                 9                   578
# ..                    ...               ...                   ...
# 220                   147                 8                   495
# 221                   745                 4                   794
# 222                   184                 3                   734
# 223                   828                 8                   540
# 224                   578                 5                   735
# 225                   491                 4                   940
# 226                    62                 4                   571
# 227                    77                 9                   888
# 228                   506                 9                   664
# 229                   271                 9                   343
# 230                   584                10                   143
# 231                   148                 5                   505
# 232                   595                 3                    54
# 233                   274                10                   959
# 234                   646                 1                   367
# 235                   520                 8                   883
# 236                   644                 8                   251
# 237                   725                 8                   855
# 238                   934                 4                   233
# 239                   151                10                   559
# 240                   945                 5                   734
# 241                   343                 3                   677
# 242                   380                 9                   276
# 243                   911                 4                    45
# 244                   621                 9                   945
# 245                   413                 9                   783
# 246                   926                 6                   556
# 247                   134                 3                   547
# 248                   396                 6                   252
# 249                   535                10                   249
#
#      Food ID - Week 2
# 0                  10
# 1                   7
# 2                  10
# 3                   5
# 4                   3
# 5                   5
# 6                   2
# 7                   5
# 8                   9
# 9                   8
# 10                  6
# 11                 10
# 12                  7
# 13                 10
# 14                  4
# 15                  2
# 16                  6
# 17                  7
# 18                  6
# 19                  9
# 20                  4
# 21                  1
# 22                  3
# 23                  9
# 24                  2
# 25                  4
# 26                  7
# 27                  2
# 28                  8
# 29                  5
# ..                ...
# 220                 2
# 221                 6
# 222                10
# 223                 3
# 224                 2
# 225                 8
# 226                 7
# 227                 2
# 228                 6
# 229                 7
# 230                 4
# 231                 3
# 232                 8
# 233                 2
# 234                 8
# 235                 8
# 236                 9
# 237                 4
# 238                 3
# 239                10
# 240                 1
# 241                 3
# 242                 4
# 243                 8
# 244                 4
# 245                10
# 246                10
# 247                 9
# 248                 9
# 249                 6
#
# [250 rows x 4 columns]

# %% [markdown]
# ## The `.join()` Method

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")
satisfaction = pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
satisfaction.head(3)
# Out:
#    Satisfaction Rating
# 0                    2
# 1                    7
# 2                    3

# %%
week1.merge(satisfaction, how = "left", left_index = True, right_index = True).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %%
week1.join(satisfaction).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %% [markdown]
# ## The `pd.merge()` Method

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")
satisfaction = pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
pd.merge(week1, customers, how = "left", left_on = "Customer ID", right_on = "ID")
# Out:
#      Customer ID  Food ID   ID First Name  Last Name  Gender       Company  \
# 0            537        9  537     Cheryl    Carroll  Female      Zoombeat
# 1             97        4   97     Amanda    Watkins  Female           Ozu
# 2            658        1  658    Patrick       Webb    Male     Browsebug
# 3            202        2  202      Louis   Campbell    Male     Rhynoodle
# 4            155        9  155    Carolyn       Diaz  Female      Gigazoom
# 5            213        8  213      Keith     Foster    Male     Gigashots
# 6            600        1  600     Sandra     Bailey  Female     Jaxnation
# 7            503        5  503     Justin    Daniels    Male          Oloo
# 8             71        3   71    Carolyn      Reyes  Female        Twimbo
# 9            174        3  174       Anna     Miller  Female       Innojam
# 10           961        9  961      Ralph   Richards    Male  Thoughtstorm
# 11           966        5  966     Robert       Ford    Male    Jabbertype
# 12           641        4  641      Donna  Gutierrez  Female       Dabtype
# 13           288        2  288    Kenneth    Jackson    Male         Voomm
# 14           149        4  149   Jennifer     Oliver  Female   Topiclounge
# 15           954        2  954     Thomas    Perkins    Male        Roodel
# 16           147        9  147    Theresa    Morales  Female         Abata
# 17           155        1  155    Carolyn       Diaz  Female      Gigazoom
# 18           550        6  550     Walter     Miller    Male          Yata
# 19           101        7  101     Jeremy     Nelson    Male   Brainlounge
# 20           549        6  549     Harold     Rivera    Male      Topdrive
# 21            75        6   75  Catherine  Carpenter  Female        Zoozzy
# 22            78        7   78     Robert    Kennedy    Male      Edgewire
# 23           514        5  514       Jack       Hill    Male      Blogtags
# 24           833        7  833    Carolyn       Dunn  Female         Yadel
# 25           329        8  329     Amanda     Nguyen  Female        Meezzy
# 26           586       10  586      Doris   Mcdonald  Female       Youfeed
# 27           341        1  341     Rachel   Robinson  Female       Twinder
# 28           519       10  519    Lillian     Rogers  Female         Eazzy
# 29           680        9  680      Irene     Gordon  Female       Voolith
# ..           ...      ...  ...        ...        ...     ...           ...
# 220          147        8  147    Theresa    Morales  Female         Abata
# 221          745        4  745     Nicole      Garza  Female     Topiczoom
# 222          184        3  184      Jesse    Edwards    Male      Zoombeat
# 223          828        8  828       Mary      Payne  Female       Oyonder
# 224          578        5  578     Donald   Matthews    Male      Fiveclub
# 225          491        4  491       Anna    Perkins  Female         Zazio
# 226           62        4   62     Andrew     Tucker    Male        Leenti
# 227           77        9   77       Lori    Edwards  Female       Dabvine
# 228          506        9  506    Mildred    Mendoza  Female          Vitz
# 229          271        9  271    Beverly       Ward  Female      Brainbox
# 230          584       10  584    Jeffrey    Simmons    Male     Flipstorm
# 231          148        5  148   Patricia       Reid  Female  Shuffledrive
# 232          595        3  595      Bruce    Kennedy    Male          Mydo
# 233          274       10  274       Gary       Reid    Male      Fivespan
# 234          646        1  646      Wanda       Lane  Female         Twiyo
# 235          520        8  520    Melissa    Wallace  Female         Skyvu
# 236          644        8  644      Louis     Brooks    Male       Nlounge
# 237          725        8  725      Carol    Russell  Female        BlogXS
# 238          934        4  934     Joseph     Burton    Male         Leexo
# 239          151       10  151    Brandon     Oliver    Male         Voomm
# 240          945        5  945       Anne       Reed  Female  Twitterworks
# 241          343        3  343        Joe      Price    Male      Fanoodle
# 242          380        9  380     Martha      Payne  Female         Quinu
# 243          911        4  911    Patrick       Reed    Male   Jabberstorm
# 244          621        9  621        Amy       Long  Female        Skidoo
# 245          413        9  413      Diane     Bailey  Female       Wikibox
# 246          926        6  926       Anne     Wagner  Female         Skyba
# 247          134        3  134      Diana       Hall  Female         Quinu
# 248          396        6  396       Juan     Romero    Male       Zoonder
# 249          535       10  535      Nancy        Cox  Female        Trudeo
#
#                          Occupation
# 0                  Registered Nurse
# 1               Account Coordinator
# 2     Community Outreach Specialist
# 3        Account Representative III
# 4        Database Administrator III
# 5                VP Quality Control
# 6                   Sales Associate
# 7                Environmental Tech
# 8              Safety Technician IV
# 9                       Developer I
# 10                     Accountant I
# 11        Account Representative IV
# 12              Assistant Professor
# 13              Associate Professor
# 14       Database Administrator III
# 15                Account Executive
# 16           Occupational Therapist
# 17       Database Administrator III
# 18   Payment Adjustment Coordinator
# 19                 Web Developer IV
# 20                  Cost Accountant
# 21                Marketing Manager
# 22                Chemical Engineer
# 23              Assistant Professor
# 24                        Recruiter
# 25              Associate Professor
# 26              Marketing Assistant
# 27             Safety Technician IV
# 28                        Paralegal
# 29        Database Administrator II
# ..                              ...
# 220          Occupational Therapist
# 221                 General Manager
# 222          Administrative Officer
# 223         Assistant Media Planner
# 224      Physical Therapy Assistant
# 225                Quality Engineer
# 226    Structural Analysis Engineer
# 227            Sales Representative
# 228              Environmental Tech
# 229        Automation Specialist II
# 230               Chemical Engineer
# 231   Analog Circuit Design manager
# 232                       Recruiter
# 233             Executive Secretary
# 234            Help Desk Technician
# 235          Administrative Officer
# 236              VP Quality Control
# 237                      Pharmacist
# 238            Compensation Analyst
# 239                Internal Auditor
# 240               Director of Sales
# 241               Marketing Manager
# 242         Assistant Media Planner
# 243         Senior Quality Engineer
# 244              Research Associate
# 245                Technical Writer
# 246                 Legal Assistant
# 247               Financial Advisor
# 248              Analyst Programmer
# 249              Research Associate
#
# [250 rows x 8 columns]
